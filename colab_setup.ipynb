# %% [markdown]
# # PDF RAG Pipeline - Colab Setup
#
# This notebook will help you run your PDF RAG Pipeline project in Google Colab.

# %% [markdown]
# ## 1. Mount Google Drive
# First, upload your entire `pdf_rag_pipeline` folder to your Google Drive. Then, mount your Google Drive below so Colab can access your files.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2. Navigate to the Project Directory
# Update the path below if you placed the `pdf_rag_pipeline` folder inside another directory in your Google Drive.

# %%
# %cd /content/drive/MyDrive/pdf_rag_pipeline
# !ls

# %% [markdown]
# ## 3. Install Requirements
# This will install all the required Python packages specified in `requirements.txt`.

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 4. Setup Environment Variables
# If your project requires a HuggingFace Token or other API keys, you can set them here. (If you have a `.env` file, the `python-dotenv` package will automatically load it).

# %%
import os
from google.colab import userdata

# Optional: Set your huggingface token (uncomment the line below)
# os.environ['HF_TOKEN'] = 'your_huggingface_token_here'

# Alternatively, use Colab Secrets (the key icon on the left sidebar)
# os.environ['HF_TOKEN'] = userdata.get('HF_TOKEN')

# %% [markdown]
# ## 5. Ingest Documents
# Run the ingestion script to process your PDFs. Make sure you have placed some PDFs in your designated content folder.

# %%
# !python ingest.py

# %% [markdown]
# ## 6. Run the Streamlit App
# To access the Streamlit app from Colab, we use `localtunnel` to expose the app to a public URL.
#
# **Instructions:**
# 1. Run the cell below.
# 2. Copy the **Endpoint IP** printed in the output.
# 3. Click the `localtunnel` URL (e.g., `https://...loca.lt`).
# 4. Paste the Endpoint IP into the webpage to access your Streamlit app.

# %%
# !npm install localtunnel
import urllib
print("\n--- COPY THIS ENDPOINT IP ---")
print(urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())
print("-----------------------------\n")
# !streamlit run app.py & npx localtunnel --port 8501
